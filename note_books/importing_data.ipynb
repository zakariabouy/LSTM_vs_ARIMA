# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# %%
# List of 10 major S&P 500 companies
tickers = [
    'AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA',
    'META', 'BRK-B', 'JPM', 'JNJ', 'V'
]

# Define time period
end_date = datetime.now()
start_date = end_date - timedelta(days=3*365)  # 3 years

# Download comprehensive data
print("Downloading data...")
data = yf.download(tickers, start=start_date, end=end_date, auto_adjust=False)
# Out:
# ...
# Failed to get ticker 'V' reason: Failed to perform, curl: (35) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# [*********************100%***********************]  10 of 10 completed

# %%
data['Close'].to_csv('top10.csv')

# %%
ticker = 'XAUT-USD'
Gold = yf.download(ticker, start=start_date, end=end_date, auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Gold.to_csv('gold_prices.csv')
